# %% [markdown]
# # NAME : Mukul Lokhande

# %% [markdown]
# # IMPORT REQUIRED MODULES

# %%
#import required modules
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

# %%
#load data
df = pd.read_csv("https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv")
df.head(10)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
#arrange data
X = df.iloc[:, :-1].values  
y = df.iloc[:, 1].values

# %% [markdown]
# # KNN REGRESSOR

# %%
#train data using knn regressor with k=5
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
knn = KNeighborsRegressor(n_neighbors = 6)
knn.fit(X_train, y_train)
#check score which is accuracy. It shows approximately 90%
knn.score(X_test, y_test)
# Out:
# 0.90831887675947087

# %%
#predict values of test data
y_pred = knn.predict(X_test)

# %% [markdown]
# # COMPARISON OF TEST DATA AND PREDICTED DATA

# %%
#comparison table to predicted score and actual score of test data
dl = pd.DataFrame({'No. of Hours':X_test.flatten(), 'Predicted Score': y_pred,'Actual Score': y_test,}) 
dl
# Out:
#    Actual Score  No. of Hours  Predicted Score
# 0            20           1.5        27.500000
# 1            27           3.2        31.500000
# 2            69           7.4        78.333333
# 3            30           2.5        27.500000
# 4            62           5.9        57.500000
# 5            35           3.8        37.000000
# 6            24           1.9        27.500000

# %% [markdown]
# # PREDICTION MODEL

# %%
#take input as hours of study and predict the score of student
x=input("Enter Hours of Study:")
print("The predicted score for {} of study is {}".format(x,knn.predict(x)))
# Out:
# Enter Hours of Study:3.4
# The predicted score for 3.4 of study is [ 31.5]

# %% [markdown]
# # GRAPH

# %%
#plot a graph
T = np.linspace(0, 10, 10)[:, np.newaxis]
y_ = knn.fit(X_train, y_train).predict(T)
plt.scatter(X_train, y_train, color='darkorange', label='data')
plt.plot(T, y_, color='navy', label='prediction')

plt.axis('tight')
plt.legend()
plt.title("KNeighborsRegressor with k = 5")


plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
